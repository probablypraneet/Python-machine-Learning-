# %%
#list

a =['Josh','Advance','Root','Hashmap']

#add update delete remove

a.append('Joshuwa')

for i in a:
    print(i)
# Out:
# Josh
# Advance
# Root
# Hashmap
# Joshuwa

# %%
#Upate the item 3 in list; Previously it was hasmap now its hello world 
a[3] = 'hello world'

for i in a:
    print(i)
# Out:
# Josh
# Advance
# Root
# hello world
# Joshuwa

# %%
a[0]='hello nepal'# this is update again

for i in a:
    print(i)
# Out:
# hello nepal
# Advance
# Root
# hello world
# Joshuwa

# %%
nameCars = ['Mitsubishi','Toyota','Subaru','Nissan','Acura']

#accessing first item of the list

itemOne = nameCars[0]

print('First item of the Data set: ',itemOne)


print(f'The list: {nameCars}')


print('the Cars List:')

for i in nameCars:
    print(i)
# Out:
# First item of the Data set:  Mitsubishi
# The list: ['Mitsubishi', 'Toyota', 'Subaru', 'Nissan', 'Acura']
# the Cars List:
# Mitsubishi
# Toyota
# Subaru
# Nissan
# Acura

# %%
print(nameCars)
# Out:
# ['Mitsubishi', 'Toyota', 'Subaru', 'Nissan', 'Acura']

# %%
#appending / adding 

nameCars.append('Honda')

# %%
print(nameCars)
# Out:
# ['Mitsubishi', 'Toyota', 'Subaru', 'Nissan', 'Acura', 'Honda']

# %%
# Printng List with while loop
i = 0
while i<len(nameCars):
    print(nameCars[i])
    i = i+1
# Out:
# Mitsubishi
# Toyota
# Subaru
# Nissan
# Acura
# Honda

# %%
# for adding we use 'append()' method

# we can also use insert() method insert(item_position, item_value)

# we can aslo use extend() to merge two lists in one  

nameList = ['alice','Aniken','Luke','Yoda']
nameList2 = ['Padme','Han Solo','Chewie']
#lets add the name Padme

nameList.extend(nameList2)

print(nameList,"\nList length: ",len(nameList))
# Out:
# ['alice', 'Aniken', 'Luke', 'Yoda', 'Padme', 'Han Solo', 'Chewie']
# List length:  7

# %%
y = 0 
while y<len(nameList):
    print(nameList[y])
    y = y+1
# Out:
# alice
# Aniken
# Luke
# Yoda
# Padme
# Han Solo
# Chewie

# %%
nameList.insert(0,'Luffy')
print(nameList[1:7])
# Out:
# ['Luffy', 'Luffy', 'Luffy', 'alice', 'Aniken', 'Luke']

# %%
y = 0 
while y<len(nameList):
    print(nameList[y])
    y = y+1
# Out:
# Luffy
# Luffy
# Luffy
# Luffy
# alice
# Aniken
# Luke
# Yoda
# Padme
# Han Solo
# Chewie

# %%
del nameList[0:3]
print(nameList)
# Out:
# ['Luffy', 'alice', 'Aniken', 'Luke', 'Yoda', 'Padme', 'Han Solo', 'Chewie']

# %%
nameList.pop()
# Out:
# 'Chewie'

# %%
print(nameList)
# Out:
# ['Luffy', 'alice', 'Aniken', 'Luke', 'Yoda', 'Padme', 'Han Solo']

# %%
nameList.append('Chewie')

# %%
y = 0 
while y<len(nameList):
    print(nameList[y])
    y = y+1
# Out:
# Luffy
# alice
# Aniken
# Luke
# Yoda
# Padme
# Han Solo
# Chewie
