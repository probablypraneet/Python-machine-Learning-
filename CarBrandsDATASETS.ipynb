# %%
import pandas as pd

# %%
DataF = pd.DataFrame({'Car Brands':['bmw','mitsubishi','ford','jeep'],'Type':['suv','sedan','hatchback','compact suv']},index=[1,2,3,4])

# %%
DataF.to_csv('CarBarndS_DataSets.csv')
